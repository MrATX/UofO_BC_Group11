# %%
import pandas as pd
file = "UNCLEANED_voter_data.csv"
voter_data = pd.read_csv(file)
voter_data = voter_data.iloc[:,:11]
voter_data.head()
voter_data = voter_data.dropna()
voter_data.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code          State  \
# 0  2016                 0                        0  United States
# 1  2016                41                        1        Alabama
# 2  2016                81                        2         Alaska
# 3  2016                61                        3        Arizona
# 4  2016                42                        4       Arkansas
#
#    VEP Total Ballots Counted  VEP Highest Office  VAP Highest Office  \
# 0                      0.601               0.592               0.547
# 1                      0.591               0.588               0.563
# 2                      0.615               0.610               0.574
# 3                      0.561               0.549               0.489
# 4                      0.532               0.528               0.494
#
#    Total Ballots Counted (Estimate)  Highest Office  \
# 0                       138846571.0     136753936.0
# ...

# %%
voter_data.to_csv("voter_data.csv",encoding="utf-8",index=False)
