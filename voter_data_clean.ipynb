# %%
import pandas as pd
file = "UNCLEANED_voter_data.csv"
voter_data = pd.read_csv(file)

voter_data.insert(3, 'Abbrv', voter_data["State Abv"])
voter_data = voter_data.iloc[:,:12]
voter_data = voter_data.dropna()
voter_data
# Out:
#      Year  ICPSR State Code  Alphanumeric State Code Abbrv          State  \
# 0    2016                 0                        0    US  United States
# 1    2016                41                        1    AL        Alabama
# 2    2016                81                        2    AK         Alaska
# 3    2016                61                        3    AZ        Arizona
# 4    2016                42                        4    AR       Arkansas
# ..    ...               ...                      ...   ...            ...
# 981  1980                67                       45    UT           Utah
# 982  1980                 6                       46    VT        Vermont
# 984  1980                73                       48    WA     Washington
# 985  1980                56                       49    WV  West Virginia
# 987  1980                68                       51    WY        Wyoming
#
#      VEP Total Ballots Counted  VEP Highest Office  VAP Highest Office  \
# 0                        0.601               0.592               0.547
# 1                        0.591               0.588               0.563
# 2                        0.615               0.610               0.574
# 3                        0.561               0.549               0.489
# 4                        0.532               0.528               0.494
# ..                         ...                 ...                 ...
# 981                      0.666               0.660               0.646
# 982                      0.593               0.587               0.578
# 984                      0.606               0.596               0.574
# 985                      0.535               0.532               0.528
# 987                      0.554               0.541               0.534
#
#      Total Ballots Counted (Estimate)  Highest Office  \
# 0                         138846571.0     136753936.0
# 1                           2134061.0       2123372.0
# 2                            321271.0        318608.0
# 3                           2661497.0       2604657.0
# 4                           1137772.0       1130635.0
# ..                                ...             ...
# 981                          609691.0        604222.0
# 982                          215500.0        213299.0
# 984                         1772904.0       1742394.0
# 985                          742150.0        737715.0
# 987                          181004.0        176713.0
#
#      Voting-Eligible Population (VEP)  Voting-Age Population (VAP)
# 0                           230931921                    250055734
# 1                             3609447                      3770142
# 2                              522679                       555367
# 3                             4740310                      5331034
# 4                             2140097                      2286625
# ..                                ...                          ...
# 981                            915484                       934767
# 982                            363143                       369147
# 984                           2923670                      3037193
# 985                           1387231                      1396595
# 987                            326644                       330784
#
# [759 rows x 12 columns]

# %%
voter_data.to_csv("voter_data.csv",encoding="utf-8",index=False)
